# %%
import pandas as pd
import os

from allennlp.data.vocabulary import Vocabulary
from annoy import AnnoyIndex

# %% [markdown]
# ## Data

# %%
DATA_DIR = "/home/jacobgdt/.cache/spotify_data/"

lyrics = pd.read_json(os.path.join(DATA_DIR, "lyrics.jsonl"), lines=True)
preds = pd.read_json(os.path.join(DATA_DIR, "pred.jsonl"), lines=True)
scores = preds.scores.apply(lambda x: dict(map(tuple, x))).apply(pd.Series)

encoded = pd.concat([lyrics, scores], axis=1).drop(columns='sentence')

print(encoded.shape)
encoded.head()
# Out:
# (7662, 51)
#                  track_id  :face_with_rolling_eyes:  :weary_face:  \
# 0  14msK75pk3pA33pzPVNtBF                  0.958762      0.038948
# 1  6MWtB6iiXyIwun0YzU6DFP                  0.058186      0.013880
# 2  4kV4N9D1iKVxx1KLvtTpjS                  0.961466      0.016553
# 3  6Qs4SXO9dwPj5GKvVOv8Ki                  0.010327      0.013254
# 4  25sgk305KZfyuqVBQIahim                  0.014516      0.011302
#
#    :face_with_tears_of_joy:  :crying_face:  :rolling_on_the_floor_laughing:  \
# 0                  0.013138       0.011640                         0.009979
# 1                  0.016922       0.014814                         0.036876
# 2                  0.007651       0.014832                         0.015082
# 3                  0.029442       0.012612                         0.214775
# 4                  0.007710       0.830548                         0.008575
#
#    :loudly_crying_face:       N/A  :sparkles:  \
# 0              0.009508  0.009136    0.009093
# 1              0.010906  0.010361    0.009912
# 2              0.010368  0.008913    0.008206
# 3              0.539007  0.006198    0.005502
# 4              0.005515  0.007044    0.008473
#
#    :smiling_face_with_smiling_eyes:  ...  :speaking_head:  :police_car_light:  \
# 0                          0.008988  ...         0.005385            0.005343
# 1                          0.007909  ...         0.009100            0.007564
# 2                          0.009855  ...         0.005967            0.005367
# 3                          0.005793  ...         0.005634            0.004837
# 4                          0.007685  ...         0.005833            0.004740
#
#    :white_heavy_check_mark:  :double_exclamation_mark:  \
# 0                  0.005280                   0.005130
# 1                  0.006588                   0.007580
# 2                  0.004822                   0.005313
# 3                  0.004321                   0.005133
# 4                  0.004794                   0.004886
#
#    :backhand_index_pointing_down:  :clapping_hands:  :heavy_check_mark:  \
# 0                        0.005087          0.005000            0.004933
# 1                        0.006248          0.007638            0.005953
# 2                        0.004804          0.005640            0.004726
# 3                        0.005103          0.005312            0.004426
# 4                        0.004434          0.005601            0.004644
#
#    :thumbs_up:  :trophy:  :male_sign:
# 0     0.004654  0.004593     0.004406
# 1     0.006309  0.007166     0.005947
# 2     0.004607  0.004154     0.004595
# 3     0.005006  0.004481     0.004035
# 4     0.004812  0.004598     0.004199
#
# [5 rows x 51 columns]

# %%
songs = pd.read_csv('https://storage.googleapis.com/jacobdanovitch/spotify_lyrics/spotify_with_genius.csv')
df = pd.merge(songs, encoded, on='track_id')

print(df.shape)
df.head()
# Out:
# (7662, 97)
#                  track_id genre    artist_name  \
# 0  14msK75pk3pA33pzPVNtBF   Pop  Ariana Grande
# 1  6MWtB6iiXyIwun0YzU6DFP   Rap    Post Malone
# 2  4kV4N9D1iKVxx1KLvtTpjS   Pop  Ariana Grande
# 3  6Qs4SXO9dwPj5GKvVOv8Ki   Pop      Sam Smith
# 4  25sgk305KZfyuqVBQIahim   Pop        Ava Max
#
#                                  track_name  popularity  acousticness  \
# 0                                   7 rings         100        0.5780
# 1                                      Wow.          99        0.1630
# 2  break up with your girlfriend, i'm bored          99        0.0421
# 3    Dancing With A Stranger (with Normani)          97        0.4500
# 4                          Sweet but Psycho          97        0.0691
#
#    danceability  duration_ms  energy  instrumentalness  ... :speaking_head:  \
# 0         0.725       178640   0.321          0.000000  ...        0.005385
# 1         0.833       149520   0.539          0.000002  ...        0.009100
# 2         0.726       190440   0.554          0.000000  ...        0.005967
# 3         0.741       171030   0.520          0.000002  ...        0.005634
# 4         0.719       187436   0.704          0.000000  ...        0.005833
#
#    :police_car_light:  :white_heavy_check_mark: :double_exclamation_mark:  \
# 0            0.005343                  0.005280                  0.005130
# 1            0.007564                  0.006588                  0.007580
# 2            0.005367                  0.004822                  0.005313
# 3            0.004837                  0.004321                  0.005133
# 4            0.004740                  0.004794                  0.004886
#
#    :backhand_index_pointing_down:  :clapping_hands: :heavy_check_mark:  \
# 0                        0.005087          0.005000           0.004933
# 1                        0.006248          0.007638           0.005953
# 2                        0.004804          0.005640           0.004726
# 3                        0.005103          0.005312           0.004426
# 4                        0.004434          0.005601           0.004644
#
#    :thumbs_up:  :trophy:  :male_sign:
# 0     0.004654  0.004593     0.004406
# 1     0.006309  0.007166     0.005947
# 2     0.004607  0.004154     0.004595
# 3     0.005006  0.004481     0.004035
# 4     0.004812  0.004598     0.004199
#
# [5 rows x 97 columns]

# %%
df.to_csv(os.path.join(DATA_DIR, 'encoded.csv'), index=False)

# %%
# !rm {os.path.join(DATA_DIR, 'encoded.csv')}

# %% [markdown]
# ## Vocab

# %%
VOCAB_DIR = os.path.join(DATA_DIR, 'vocab')
os.makedirs(VOCAB_DIR, exist_ok=True)

with open(os.path.join(VOCAB_DIR, 'track_ids.txt'), 'w') as f:
    f.writelines('\n'.join(df.track_id.unique()))

# %%
help(vocab.set_from_file)
# Out:
# Help on method set_from_file in module allennlp.data.vocabulary:
#
# set_from_file(filename: str, is_padded: bool = True, oov_token: str = '@@UNKNOWN@@', namespace: str = 'tokens') method of allennlp.data.vocabulary.Vocabulary instance
#     If you already have a vocabulary file for a trained model somewhere, and you really want to
#     use that vocabulary file instead of just setting the vocabulary from a dataset, for
#     whatever reason, you can do that with this method.  You must specify the namespace to use,
#     and we assume that you want to use padding and OOV tokens for this.
#
#     # Parameters
#
#     filename : `str`
#         The file containing the vocabulary to load.  It should be formatted as one token per
#         line, with nothing else in the line.  The index we assign to the token is the line
#         number in the file (1-indexed if `is_padded`, 0-indexed otherwise).  Note that this
#         file should contain the OOV token string!
#     is_padded : `bool`, optional (default=True)
#         Is this vocabulary padded?  For token / word / character vocabularies, this should be
#         `True`; while for tag or label vocabularies, this should typically be `False`.  If
#         `True`, we add a padding token with index 0, and we enforce that the `oov_token` is
#         present in the file.
#     oov_token : `str`, optional (default=DEFAULT_OOV_TOKEN)
#         What token does this vocabulary use to represent out-of-vocabulary characters?  This
#         must show up as a line in the vocabulary file.  When we find it, we replace
#         `oov_token` with `self._oov_token`, because we only use one OOV token across
#         namespaces.
#     namespace : `str`, optional (default="tokens")
#         What namespace should we overwrite with this vocab file?

# %%
vocab = Vocabulary()
vocab.set_from_file(os.path.join(VOCAB_DIR, 'track_ids.txt'), is_padded=False, namespace="labels")
vocab
# Out:
# Vocabulary with namespaces:  labels, Size: 7662 || Non Padded Namespaces: {'*tags', '*labels'}

# %%
vocab.save_to_files(os.path.join(VOCAB_DIR, 'vocab'))

# %%
os.path.join(VOCAB_DIR, 'vocab')
# Out:
# '/home/jacobgdt/.cache/spotify_data/vocab/vocab'

# %% [markdown]
# ## Index

# %%
index = AnnoyIndex(scores.shape[-1], metric='angular')
vectors = encoded.set_index("track_id")

# %%
from tqdm.auto import tqdm

for track in tqdm(df.track_id.unique()):
    i = vocab.get_token_to_index_vocabulary("labels")[track]
    index.add_item(i, vectors.loc[track])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=7662.0), HTML(value='')))

# %%
index.build(-1)
index.save(os.path.join(DATA_DIR, 'index.tree'))
# Out:
# True

# %%
nns = index.get_nns_by_item(0, 10)
nns
# Out:
# [6259, 1408, 543, 3927, 7032, 1928, 4376, 3756, 1781, 3327]

# %%
# !ls {VOCAB_DIR}/vocab
# Out:
# labels.txt  non_padded_namespaces.txt

# %% [markdown]
# ## Predictor

# %%
from overrides import overrides

from allennlp.common.util import JsonDict
from allennlp.data import Instance, DatasetReader
from allennlp.predictors.predictor import Predictor
from allennlp.models import Model

import pandas as pd
from annoy import AnnoyIndex

# @Predictor.register('knn')
class KNNPredictor(Predictor):
    def __init__(self, 
                 model: Model, 
                 dataset_reader: DatasetReader,
                 vocab: Vocabulary,
                  annoy_index_fp: str,
                 dim: int,
                 df_fp: str
                ) -> None:
        super().__init__(model, dataset_reader)
        
        self.vocab = vocab
        self.df = pd.read_csv(df_fp).set_index("track_id")
        
        self.index = AnnoyIndex(dim, metric='angular')
        self.index.load(annoy_index_fp)
    
    def predict_json(self, inputs: JsonDict) -> JsonDict:
        if 'track_id' in inputs:
            idx = self.vocab.get_token_to_index_vocabulary("labels")[inputs['track_id']]
            tracks = [vocab.get_token_from_index(i, "labels") for i in nns]
            return self.df.loc[tracks].reset_index(drop=True).to_dict(orient='records')
            
        instance = self._json_to_instance(inputs)
        output_dict = self.predict_instance(instance)
        #label_dict = self._model.vocab.get_index_to_token_vocabulary('labels')
        #all_labels = [label_dict[i] for i in range(len(label_dict))]
        #output_dict["all_labels"] = all_labels
        return output_dict

    @overrides
    def _json_to_instance(self, json_dict: JsonDict) -> Instance:
        return self._dataset_reader.text_to_instance(text=json_dict['query'])

# %%
# %cd ~/bertmoji
# Out:
# /home/jacobgdt/bertmoji

# %%
from allennlp.models import load_archive
from my_library.models import BERTMoji
from my_library.dataset_readers import TwitterDatasetReader

knn_pred = KNNPredictor(load_archive(DATA_DIR + 'saved_model').model, 
                        TwitterDatasetReader(),
                        vocab,
                        DATA_DIR+'index.tree',
                        50,
                        'https://storage.googleapis.com/jacobdanovitch/spotify_lyrics/spotify_with_genius.csv'
)

# %%
knn_pred.predict_json({'track_id': df.track_id[0]})
# Out:
# [{'genre': 'Alternative',
#   'artist_name': 'Nine Inch Nails',
#   'track_name': 'Something I Can Never Have',
#   'popularity': 41,
#   'acousticness': 0.815,
#   'danceability': 0.501,
#   'duration_ms': 354933,
#   'energy': 0.131,
#   'instrumentalness': 6.12e-05,
#   'key': 'F',
#   'liveness': 0.111,
#   'loudness': -16.824,
#   'mode': 'Major',
#   'speechiness': 0.0302,
#   'tempo': 108.051,
#   'time_signature': '4/4',
#   'valence': 0.0391,
#   'Alternative': 1,
#   'Anime': 0,
#   'Blues': 0,
#   'Children’s Music': 0,
#   'Classical': 0,
#   'Country': 0,
#   'Dance': 0,
#   'Electronic': 0,
#   'Folk': 0,
#   'Hip-Hop': 0,
#   'Indie': 0,
#   'Jazz': 0,
#   'Movie': 0,
#   'Pop': 0,
#   'R&B': 0,
#   'Rap': 0,
#   'Reggae': 0,
#   'Reggaeton': 0,
#   'Rock': 0,
#   'Ska': 0,
#   'Soul': 0,
#   'Soundtrack': 0,
#   'World': 0,
#   'api_path': '/songs/174672',
#   'apple_music_id': 900248433.0,
#   'apple_music_player_url': 'https://genius.com/songs/174672/apple_music_player',
#   'lyrics_url': 'https://genius.com/Nine-inch-nails-something-i-can-never-have-lyrics',
#   'spotify_url': 'https://open.spotify.com/track/6azwgyc7oNJvcsYyzqkiA5',
#   'lyrics': "\n\n[Verse 1]\nI still recall the taste of your tears\nEchoing your voice just like the ringing in my ears\nMy favorite dreams of you still wash ashore\nScraping through my head 'til I don't want to sleep anymore\n\n[Chorus]\nYou make this all go away\nYou make this all go away\nI'm down to just one thing\nAnd I'm starting to scare myself\nYou make this all go away\nYou make this all go away\nI just want something\nI just want something I can never have\n\n[Verse 2]\nYou always were the one to show me how\nBack then I couldn't do the things that I can do now\nThis thing is slowly taking me apart\nGrey would be the color if I had a heart\nCome on, tell me!\n\n[Chorus]\nYou make this all go away\nYou make this all go away\nI'm down to just one thing\nAnd I'm starting to scare myself\nYou make this all go away\nYou make this all go away\nI just want something\nI just want something I can never have\n\n[Verse 3]\nIn this place it seems like such a shame\nThough it all looks different now, I know it's still the same\nEverywhere I look you're all I see\nJust a fading fucking reminder of who I used to be\nCome on, tell me!\n\n[Chorus]\nYou make this all go away\nYou make this all go away\nI'm down to just one thing\nAnd I'm starting to scare myself\nYou make this all go away\nYou make it all go away\nI just want something\nI just want something I can never have\nI just want something I can never have\n\n"},
#  {'genre': 'Pop',
#   'artist_name': 'Shawn Mendes',
#   'track_name': 'Imagination',
#   'popularity': 63,
#   'acousticness': 0.0743,
#   'danceability': 0.481,
#   'duration_ms': 217773,
#   'energy': 0.455,
#   'instrumentalness': 0.0,
#   'key': 'C',
#   'liveness': 0.0694,
#   'loudness': -5.942,
#   'mode': 'Major',
#   'speechiness': 0.0286,
#   'tempo': 179.468,
#   'time_signature': '4/4',
#   'valence': 0.333,
#   'Alternative': 0,
#   'Anime': 0,
#   'Blues': 0,
#   'Children’s Music': 0,
#   'Classical': 0,
#   'Country': 0,
#   'Dance': 1,
#   'Electronic': 0,
#   'Folk': 0,
#   'Hip-Hop': 0,
#   'Indie': 0,
#   'Jazz': 0,
#   'Movie': 0,
#   'Pop': 1,
#   'R&B': 0,
#   'Rap': 0,
#   'Reggae': 0,
#   'Reggaeton': 0,
#   'Rock': 0,
#   'Ska': 0,
#   'Soul': 0,
#   'Soundtrack': 0,
#   'World': 0,
#   'api_path': '/songs/745068',
#   'apple_music_id': 1081579342.0,
#   'apple_music_player_url': 'https://genius.com/songs/745068/apple_music_player',
#   'lyrics_url': 'https://genius.com/Shawn-mendes-imagination-lyrics',
#   'spotify_url': 'https://open.spotify.com/track/21TcDbGosp7w9YhTjOszgA',
#   'lyrics': "\n\n[Verse 1]\nOh, there she goes again, every morning it's the same\nYou walk on by my house, I wanna call out your name\nI wanna tell you how beautiful you are from where I'm standin'\nYou got me thinkin' what we could be 'cause\n\n[Pre-Chorus]\nI keep craving, craving, you don't know it but it's true\nCan't get my mouth to say the words they wanna say to you\nThis is typical of love, I can't wait anymore, won't wait\nI need to tell you how I feel when I see us together forever\n\n[Chorus]\nIn my dreams you're with me, we'll be everything I want us to be\nAnd from there, who knows?\nMaybe this will be the night that we kiss for the first time\nOr is that just me and my imagination?\n\n[Verse 2]\nWe walk, we laugh, we spend our time walking by the ocean side\nOur hands are gently intertwined, a feeling I just can't describe\nAnd all this time we spent alone thinkin' we cannot belong\nTo something so damn beautiful, so damn beautiful\n\n[Pre-Chorus]\nI keep craving, craving, you don't know it but it's true\nCan't get my mouth to say the words they wanna say to you\nThis is typical of love, I can't wait anymore, won't wait\nI need to tell you how I feel when I see us together forever\n\n[Chorus]\nIn my dreams you're with me, we'll be everything I want us to be\nAnd from there, who knows?\nMaybe this will be the night that we kiss for the first time\nOr is that just me and my imagination? (Woah, oh)\n\n[Bridge]\nImagination (Woah, oh, woah, oh)\nImagination (Woah, oh)\n(Woah, oh, woah, oh, woah, oh, ooh)\n\n[Chorus]\nIn my dreams you're with me, we'll be everything I want us to be\nAnd from there, who knows?\nMaybe this will be the night that we kiss for the first time\nOr is that just me and my imagination?\n\n[Outro]\nI keep craving, craving, you don't know it but it's true\nCan't get my mouth to say the words they wanna say to you\n\n"},
#  {'genre': 'Hip-Hop',
#   'artist_name': 'Yelawolf',
#   'track_name': 'Heartbreak',
#   'popularity': 53,
#   'acousticness': 0.0471,
#   'danceability': 0.821,
#   'duration_ms': 265627,
#   'energy': 0.779,
#   'instrumentalness': 0.0,
#   'key': 'C#',
#   'liveness': 0.109,
#   'loudness': -3.248,
#   'mode': 'Major',
#   'speechiness': 0.121,
#   'tempo': 75.498,
#   'time_signature': '4/4',
#   'valence': 0.393,
#   'Alternative': 0,
#   'Anime': 0,
#   'Blues': 0,
#   'Children’s Music': 0,
#   'Classical': 0,
#   'Country': 0,
#   'Dance': 0,
#   'Electronic': 0,
#   'Folk': 0,
#   'Hip-Hop': 1,
#   'Indie': 0,
#   'Jazz': 0,
#   'Movie': 0,
#   'Pop': 0,
#   'R&B': 0,
#   'Rap': 0,
#   'Reggae': 0,
#   'Reggaeton': 0,
#   'Rock': 0,
#   'Ska': 0,
#   'Soul': 0,
#   'Soundtrack': 0,
#   'World': 0,
#   'api_path': '/songs/748381',
#   'apple_music_id': 1436731812.0,
#   'apple_music_player_url': 'https://genius.com/songs/748381/apple_music_player',
#   'lyrics_url': 'https://genius.com/Yelawolf-heartbreak-lyrics',
#   'spotify_url': 'https://open.spotify.com/track/75w2a0xsIuUVGwTYKEOqzg',
#   'lyrics': "\n\n[Verse 1]\nYou used to be so cool, what the fuck happened to you?\nLook at what all this rapping and money-stacking will do\nI could've been stuck out in 'Bama, had I not flew the coop\nAnd my babies would suffer Christmas cause Santa ain't got no loot\nUh, 'money ain't the issue' you said, that's funny now\nCause money's all I could give you to shut your motherfucking mouth\nHere, take 20 grand and buy yourself a lawyer\nShit, here's a whip so my kids ain't gotta walk to the store for ya, fuck\nMomma told me I should keep it real\nMy record ain't selling, momma, I'm trying hard enough to keep a deal\nMeanwhile I'm throwing paper down into an empty pit\nI got a business I'm trying to run, man, fuck this bitch\nI should've seen it coming, she never pulled her weight\nI'm carrying her like an elephant on a dinner plate\nYou gassed em, Yelawolf, you better pump your fucking brakes, asshole\nYou got the nerve to\n\n[Hook 1]\nWanna talk about heartbreak, oh, oh\nBaby, I've been around, you know I've been around\nAnd I can't pretend to love you right now\nSo you can go cry your heart out until you drown\nHope you can swim it out cause I can't be friends with a friend like you tryna hold me down\n\n[Verse 2]\nYou got some nerve to be mad at me for, fuck, anything\nWhat have I done besides give you what I could not afford?\nThe kids are happy cause they really don't know anything\nIf they only knew what toys that their momma could afford\nThe vacation they could be taking when daddy's on tour\nWait, you are on vacation, that's what this shit is for\nI get it, I'm like the fountain of youth\nYou're in the bed with your boo and you two are sipping courvoisier, true?\nThis song ain't no diss, it's a living proof\nSkit of skin and tooth, the witch in you bit, left me with cracked roofs\nI ain't done, bitch, put this shit in loop\nHere's a melody so it sticks in your head like your tracks do, ooh\n\n[Post-Verse]\nYou wanna walk around like it's all good\nCause I'm the golden ticket to get out of the hood\nYou better hope somebody cares more than I do\nCause my will don't include you\n\n[Hook 1]\nWanna talk about heartbreak, oh, oh\nBaby, I've been around, you know I've been around\nAnd I can't pretend to love you right now\nSo you can go cry your heart out until you drown\nHope you can swim it out cause I can't be friends with a friend like you tryna hold me down\n\n[Hook 2]\nThere ain't no fucking way I'mma let you take this hard-earned money, bitch\nAnd I can't pretend to love you right now\nSo you can go cry your heart out until you drown\nHope you can swim it out cause I can't be friends with a friend like you tryna hold me down\n\nHold up, wait a minute, let me drop this shit up in it\n\n[Bridge]\nThere'll always be a special place\nFor you in my bank account\nYou fucking bitch\n\n[Hook 1]\nWanna talk about heartbreak, oh, oh\nBaby, I've been around, you know I've been around\nAnd I can't pretend to love you right now\nSo you can go cry your heart out until you drown\nHope you can swim it out cause I can't be friends with a friend like you tryna hold me down\n\n[Hook 2]\nThere ain't no fucking way I'mma let you take this hard-earned money, bitch\nAnd I can't pretend to love you right now\nSo you can go cry your heart out until you drown\nHope you can swim it out cause I can't be friends with a friend like you tryna hold me down\n\n"},
#  {'genre': 'R&B',
#   'artist_name': 'Sinead Harnett',
#   'track_name': 'No Other Way',
#   'popularity': 57,
#   'acousticness': 0.241,
#   'danceability': 0.632,
#   'duration_ms': 199947,
#   'energy': 0.526,
#   'instrumentalness': 0.0,
#   'key': 'D#',
#   'liveness': 0.223,
#   'loudness': -8.645,
#   'mode': 'Minor',
#   'speechiness': 0.282,
#   'tempo': 181.921,
#   'time_signature': '4/4',
#   'valence': 0.499,
#   'Alternative': 1,
#   'Anime': 0,
#   'Blues': 0,
#   'Children’s Music': 1,
#   'Classical': 0,
#   'Country': 0,
#   'Dance': 0,
#   'Electronic': 0,
#   'Folk': 0,
#   'Hip-Hop': 0,
#   'Indie': 1,
#   'Jazz': 0,
#   'Movie': 0,
#   'Pop': 0,
#   'R&B': 1,
#   'Rap': 0,
#   'Reggae': 0,
#   'Reggaeton': 0,
#   'Rock': 0,
#   'Ska': 0,
#   'Soul': 0,
#   'Soundtrack': 0,
#   'World': 0,
#   'api_path': '/songs/907488',
#   'apple_music_id': 921118926.0,
#   'apple_music_player_url': 'https://genius.com/songs/907488/apple_music_player',
#   'lyrics_url': 'https://genius.com/Sinead-harnett-no-other-way-lyrics',
#   'spotify_url': 'https://open.spotify.com/track/5LuXEmya3JlX3ZfdudPAbO',
#   'lyrics': "\n\n[Verse 1]\nTell me what's on your mind\nCause I'm not going nowhere tonight\nTake as long as you need\nLet me be your therapy\n\n[Pre-Chorus]\nWhatever has thrown you down\nYou can turn it around right here\n\n[Chorus]\nCause it won't be no other way\nWhen you can't find the words to say\nLet your head go, just let go\nOf what you're holding on, holding on\nCome lay down next to me\nYou're only gonna find yourself some peace\nIf you let go, really let go\nOf what you’re holding on, holding on oh\n\n[Verse 2]\nI know you like to keep these feelings at bay\nBut you don't need to be afraid\nCause nothing that you you could ever change\nThe way that I feel, the way that feel about you\n\n[Pre-Chorus]\nWhatever has thrown you down\nYou can turn it around right here\n\n[Chorus]\nCause it won't be no other way\nWhen you can't find the words to say\nLet your head go, just let go\nOf what you're holding on, holding on\nCome lay down next to me\nYou're only gonna find yourself some peace\nIf you let go, really let go\nOf what you’re holding on, holding on oh\n\n[Bridge]\nAnd I don't mind\nWhen you get like this sometimes\nCause I know that you're more\nThan what you're making yourself out to be\n\n[Chorus]\nCause it won't be no other way\nWhen you can't find the words to say\nLet your head go, just let go\nOf what you're holding on, holding on\nCome lay down next to me\nYou're only gonna find yourself some peace\nIf you let go, really let go\nOf what you’re holding on, holding on oh (hey)\nCause it won't be no other way\nWhen you can't find the words to say\nLet your head go, just let go\nOf what you're holding on, holding on\nCome lay down next to me\nYou're only gonna find yourself some peace\nIf you let go, really let go\nOf what you’re holding on, holding on oh\n\n"},
#  {'genre': 'Indie',
#   'artist_name': 'The Lumineers',
#   'track_name': "Ain't Nobody's Problem",
#   'popularity': 51,
#   'acousticness': 0.446,
#   'danceability': 0.507,
#   'duration_ms': 296360,
#   'energy': 0.589,
#   'instrumentalness': 0.000241,
#   'key': 'A',
#   'liveness': 0.32299999999999995,
#   'loudness': -11.285,
#   'mode': 'Minor',
#   'speechiness': 0.0482,
#   'tempo': 135.30100000000002,
#   'time_signature': '4/4',
#   'valence': 0.334,
#   'Alternative': 0,
#   'Anime': 0,
#   'Blues': 0,
#   'Children’s Music': 0,
#   'Classical': 0,
#   'Country': 0,
#   'Dance': 0,
#   'Electronic': 0,
#   'Folk': 1,
#   'Hip-Hop': 0,
#   'Indie': 1,
#   'Jazz': 0,
#   'Movie': 0,
#   'Pop': 0,
#   'R&B': 0,
#   'Rap': 0,
#   'Reggae': 0,
#   'Reggaeton': 0,
#   'Rock': 0,
#   'Ska': 0,
#   'Soul': 0,
#   'Soundtrack': 0,
#   'World': 0,
#   'api_path': '/songs/207482',
#   'apple_music_id': 933305940.0,
#   'apple_music_player_url': 'https://genius.com/songs/207482/apple_music_player',
#   'lyrics_url': 'https://genius.com/The-lumineers-aint-nobodys-problem-lyrics',
#   'spotify_url': 'https://open.spotify.com/track/2Be9G8jMZTS1GlhZmBWeU4',
#   'lyrics': '\n\n[Chorus]\nWell, I ain’t nobody’s problem but my own\nSaid I ain’t nobody’s problem but my own\nSaid I ain’t nobody’s issue, don’t you come around babe, I don’t miss you at all\nI ain’t nobody’s problem but my own\n\n[Verse 1]\nWell I found myself a place\nEvery smile that you waste\nAnd every other careless look you’ve ever tossed aside\nWell in my heart I know it’s true\nThat I can’t go on loving you\nAnd that’s the truth it don’t feel good, but honey it feels right\n\n[Chorus]\nCause I ain’t nobody’s problem but my own\nSaid I ain’t nobody’s problem but my own\nSaid I ain’t nobody’s issue, don’t you come around babe, I don’t miss you at all\nI ain’t nobody’s problem but my own\n\n[Verse 2]\nWell of love I’ve had my share I’ve got plenty of people really who care\nAt times I might get wicked in my pride\nBut I smoke that mountain air honey I’ve been here, and I’ve been there\nAt times I might get lonely honey I don’t cry\n\n[Chorus]\nCause I ain’t nobody’s problem but my own\nSaid I ain’t nobody’s problem but my own\nSaid I ain’t nobody’s issue, don’t you come around babe, I don’t miss you at all\nI ain’t nobody’s problem but my own\n\n[Verse 3]\nThere’s times at night when it’s cold outside, the moon don’t shine, the winds are crying\nI wonder if you’re at home you might let me back inside\nWe can huddle up by the old stove we can kindle up some burned out coals\nWe can love our selves like the days are warm\nSaid, No no no no no\n\n[Chorus]\nCause I ain’t nobody’s problem but my own\nSaid I ain’t nobody’s problem but my own\nSaid I ain’t nobody’s issue, don’t you come around babe, I don’t miss you at all\nI ain’t nobody’s problem but my own\n\n[Chorus Louder]\nWell, I ain’t nobody’s problem but my own\nSaid I ain’t nobody’s problem but my own\nSaid I ain’t nobody’s issue, don’t you come around babe, I don’t miss you at all\nI ain’t nobody’s problem but my own\n\n'},
#  {'genre': 'Indie',
#   'artist_name': 'Death Cab for Cutie',
#   'track_name': 'No Room In Frame',
#   'popularity': 50,
#   'acousticness': 0.196,
#   'danceability': 0.642,
#   'duration_ms': 245280,
#   'energy': 0.721,
#   'instrumentalness': 0.474,
#   'key': 'E',
#   'liveness': 0.0926,
#   'loudness': -9.765,
#   'mode': 'Major',
#   'speechiness': 0.0434,
#   'tempo': 124.997,
#   'time_signature': '4/4',
#   'valence': 0.438,
#   'Alternative': 0,
#   'Anime': 0,
#   'Blues': 0,
#   'Children’s Music': 0,
#   'Classical': 0,
#   'Country': 0,
#   'Dance': 0,
#   'Electronic': 0,
#   'Folk': 1,
#   'Hip-Hop': 0,
#   'Indie': 1,
#   'Jazz': 0,
#   'Movie': 0,
#   'Pop': 0,
#   'R&B': 0,
#   'Rap': 0,
#   'Reggae': 0,
#   'Reggaeton': 0,
#   'Rock': 0,
#   'Ska': 0,
#   'Soul': 0,
#   'Soundtrack': 0,
#   'World': 0,
#   'api_path': '/songs/710522',
#   'apple_music_id': 958998204.0,
#   'apple_music_player_url': 'https://genius.com/songs/710522/apple_music_player',
#   'lyrics_url': 'https://genius.com/Death-cab-for-cutie-no-room-in-frame-lyrics',
#   'spotify_url': 'https://open.spotify.com/track/7DkTneByAopqOjXFG6XlZK',
#   'lyrics': "\n\n[Verse 1]\nI don’t know where to begin\nThere’s too many things that I can’t remember\nAs I disappeared like a trend\nIn the hum of the five in the early morning\nAnd now I'm taking my time\nUp through Coalinga, through the valley\nThis highway lived in my mind\nIt takes me back to the place that made me\n\n[Chorus]\nWas I in your way?\nWhen the cameras turned to face you\nNo room in frame\nFor two\n\n[Verse 2]\nYou cannot outrun a ghost\nSpeeding southbound lanes with abandon\nIt catches you on the coast\nOr on the cliffs of the palisades, you killed the engine\nAnd then it hovers above\nReeling bodies failing to discover\nThe thing they once knew was love\nRaising their voices to convince one another\n\n[Chorus]\nWas I in your way?\nWhen the cameras turned to face you\nNo room in frame\nFor two\n\n[Bridge]\nHow can I stay\nIn the sun, when the rain flows\nAll through my veins?\nIt's true\nAnd I guess it's not a failure we could help\nAnd we will both go on to get lonely with someone else\nWith someone else\n\n[Chorus]\nWas I in your way?\nWhen the cameras turned to face you\nNo room in frame\nFor two\n\n[Outro]\nHow can I stay\nIn the sun, when the rain flows\nAll through my veins?\nIt's true\nAnd I guess it's not a failure we could help\nAnd we will both go on to get lonely with someone else\n\n"},
#  {'genre': 'Pop',
#   'artist_name': 'Lizzo',
#   'track_name': 'Good as Hell',
#   'popularity': 72,
#   'acousticness': 0.285,
#   'danceability': 0.684,
#   'duration_ms': 159011,
#   'energy': 0.905,
#   'instrumentalness': 0.0,
#   'key': 'C',
#   'liveness': 0.525,
#   'loudness': -3.187,
#   'mode': 'Minor',
#   'speechiness': 0.0765,
#   'tempo': 95.985,
#   'time_signature': '4/4',
#   'valence': 0.4920000000000001,
#   'Alternative': 0,
#   'Anime': 0,
#   'Blues': 0,
#   'Children’s Music': 0,
#   'Classical': 0,
#   'Country': 0,
#   'Dance': 1,
#   'Electronic': 0,
#   'Folk': 0,
#   'Hip-Hop': 0,
#   'Indie': 0,
#   'Jazz': 0,
#   'Movie': 0,
#   'Pop': 1,
#   'R&B': 0,
#   'Rap': 0,
#   'Reggae': 0,
#   'Reggaeton': 0,
#   'Rock': 0,
#   'Ska': 0,
#   'Soul': 0,
#   'Soundtrack': 0,
#   'World': 0,
#   'api_path': '/songs/2438187',
#   'apple_music_id': 1150159755.0,
#   'apple_music_player_url': 'https://genius.com/songs/2438187/apple_music_player',
#   'lyrics_url': 'https://genius.com/Lizzo-good-as-hell-lyrics',
#   'spotify_url': 'https://open.spotify.com/track/6uAm7pG66O1XesXS9bpHSF',
#   'lyrics': "\n\n[Chorus]\nI do my hair toss, check my nails\nBaby, how you feelin'? (Feelin' good as hell)\nHair toss, check my nails\nBaby, how you feelin'? (Feelin' good as hell)\n\n[Verse 1]\nWoo, child, tired of the bullshit\nGo on, dust your shoulders off, keep it moving\nYes, Lord, tryna get some new shit\nIn there, swimwear, going-to-the-pool shit\nCome now, come dry your eyes\nYou know you a star, you can touch the sky\nI know that it's hard, but you have to try\nIf you need advice, let me simplify\n\n[Pre-Chorus]\nIf he don't love you anymore\nJust walk your fine ass out the door\n\n[Chorus]\nI do my hair toss, check my nails\nBaby, how you feelin'? (Feelin' good as hell)\nHair toss, check my nails\nBaby, how you feelin'? (Feelin' good as hell)\n(Feeling good as hell)\nBaby, how you feelin'? (Feelin' good as hell)\n\n[Verse 2]\nWoo, girl, need to kick off your shoes\nGotta take a deep breath, time to focus on you\nAll the big fights, long nights that you been through\nI got a bottle of tequila I been saving for you\nBoss up and change your life\nYou can have it all, no sacrifice\nI know he did you wrong, we can make it right\nSo go and let it all hang out tonight\n\n[Pre-Chorus]\n'Cause he don't love you anymore\nSo walk your fine ass out the door\n\n[Chorus]\nAnd do your hair toss, check my nails\nBaby, how you feelin'? (Feelin' good as hell)\nHair toss, check my nails\nBaby, how you feelin'? (Feelin' good as hell) (Show it off tonight)\nHair toss, check my nails\nBaby, how you feelin'? (Feelin' good as hell) (And we gon' be alright)\nHair toss, check my nails\nBaby, how you feelin'? (Feelin' good as hell)\n\n[Pre-Chorus]\nMmm, yeah, alright\nListen, if he don't love you anymore\nThen walk your fine ass out the door\n\n[Chorus]\nAnd do your hair toss, check my nails\nBaby, how you feelin'? (Feelin' good as hell) (Woo-hoo)\nHair toss, check my nails\nBaby, how you feelin'? (Feelin' good as hell) (Show it off tonight)\nHair toss, check my nails\nBaby, how you feelin'? (Feelin' good as hell) (And we gon' make it right)\nHair toss, check my nails\nBaby, how you feelin'? (Feelin' good as hell)\n(Feelin' good as hell)\nBaby, how you feelin'? (Feelin' good as hell)\n\n"},
#  {'genre': 'Rock',
#   'artist_name': 'Brad Paisley',
#   'track_name': 'Letter to Me',
#   'popularity': 52,
#   'acousticness': 0.6759999999999999,
#   'danceability': 0.532,
#   'duration_ms': 280827,
#   'energy': 0.4920000000000001,
#   'instrumentalness': 6.12e-05,
#   'key': 'A',
#   'liveness': 0.086,
#   'loudness': -9.255,
#   'mode': 'Major',
#   'speechiness': 0.0312,
#   'tempo': 79.242,
#   'time_signature': '4/4',
#   'valence': 0.366,
#   'Alternative': 0,
#   'Anime': 0,
#   'Blues': 0,
#   'Children’s Music': 0,
#   'Classical': 0,
#   'Country': 1,
#   'Dance': 0,
#   'Electronic': 0,
#   'Folk': 0,
#   'Hip-Hop': 0,
#   'Indie': 0,
#   'Jazz': 0,
#   'Movie': 0,
#   'Pop': 0,
#   'R&B': 0,
#   'Rap': 0,
#   'Reggae': 0,
#   'Reggaeton': 0,
#   'Rock': 1,
#   'Ska': 0,
#   'Soul': 0,
#   'Soundtrack': 0,
#   'World': 0,
#   'api_path': '/songs/198344',
#   'apple_music_id': 279344516.0,
#   'apple_music_player_url': 'https://genius.com/songs/198344/apple_music_player',
#   'lyrics_url': 'https://genius.com/Brad-paisley-letter-to-me-lyrics',
#   'spotify_url': 'https://open.spotify.com/track/7wqMZWYeBxJt0obQPnF5NX',
#   'lyrics': "\n\n[Verse 1]\nIf I could write a letter to me\nAnd send it back in time to myself at seventeen\nFirst I'd prove it's me by sayin' look under your bed\nThere's a Skoal can and a Playboy no one else would know you hid\nAnd then I'd say I know it's tough\nWhen you break up after seven months\nAnd yeah, I know you really liked her and it just don't seem fair\nBut all I can say is pain like that is fast and it's rare\n\n[Chorus]\nAnd, oh, you've got so much goin' for you, goin' right\nBut I know at seventeen it's hard to see past Friday night\nShe wasn't right for you and still you feel like there's a knife\nStickin' out of your back and you're wonderin' if you'll survive\nBut you'll make it through this and you'll see\nYou're still around to write this letter to me\n\n[Verse 2]\nAt the stop sign at Tomlinson and Eighth\nAlways stop completely, don't just tap your brakes\nAnd when you get a date with Bridgett, make sure the tank is full\nOn second thought forget it, that one turns out kinda cool\nEach and every time you have a fight\nJust assume you're wrong and dad is right\nAnd you should really thank Mrs. Brinkman, she spends so much extra time\nIt's like she sees the diamond underneath and she's polishing you 'til you shine\n\n[Chorus 2]\nAnd, oh, you've got so much goin' for you, goin' right\nBut I know at seventeen it's hard to see past Friday night\nTonight's the bonfire rally but you're stayin' home instead\nBecause if you fail Algebra, mom and dad will kill you dead\nTrust me you'll squeak by and get a C\nAnd you're still around to write this letter to me\n\n[Verse 3]\nYou've got so much up ahead, you'll make new friends\nYou should see your kids and wife\nAnd I'd end up sayin' have no fear\nThese are nowhere near the best years of your life\n\n[Bridge]\nI guess I'll see you in the mirror, when you're a grown man\nP.S.: Go hug Aunt Rita every chance you can\n\n[Chorus]\nAnd, oh, you've got so much goin' for you, goin' right\nBut I know at seventeen it's hard to see past Friday night\nI wish you'd study Spanish, I wish you'd taken typin' class\nI wish you wouldn't worry, let it be, hey I'd say have a little faith and you'll see\n\n[Outro]\nIf I could write a letter to me\nTo me\n\n"},
#  {'genre': 'Rock',
#   'artist_name': 'The Black Keys',
#   'track_name': "I'm Not The One",
#   'popularity': 48,
#   'acousticness': 0.5429999999999999,
#   'danceability': 0.604,
#   'duration_ms': 229213,
#   'energy': 0.406,
#   'instrumentalness': 0.000545,
#   'key': 'A',
#   'liveness': 0.0932,
#   'loudness': -10.016,
#   'mode': 'Minor',
#   'speechiness': 0.0306,
#   'tempo': 139.89700000000002,
#   'time_signature': '4/4',
#   'valence': 0.474,
#   'Alternative': 1,
#   'Anime': 0,
#   'Blues': 1,
#   'Children’s Music': 1,
#   'Classical': 0,
#   'Country': 0,
#   'Dance': 0,
#   'Electronic': 0,
#   'Folk': 0,
#   'Hip-Hop': 0,
#   'Indie': 1,
#   'Jazz': 0,
#   'Movie': 0,
#   'Pop': 0,
#   'R&B': 0,
#   'Rap': 0,
#   'Reggae': 0,
#   'Reggaeton': 0,
#   'Rock': 1,
#   'Ska': 0,
#   'Soul': 0,
#   'Soundtrack': 0,
#   'World': 0,
#   'api_path': '/songs/194800',
#   'apple_music_id': 1052966906.0,
#   'apple_music_player_url': 'https://genius.com/songs/194800/apple_music_player',
#   'lyrics_url': 'https://genius.com/The-black-keys-im-not-the-one-lyrics',
#   'spotify_url': 'https://open.spotify.com/track/4c15DmbPf9g3HNPipLBBu0',
#   'lyrics': "\n\n[Verse 1]\nI've been tried, and I've been tested\nI was born tired, I never got rested\nHarder than marble stone\nI'm better off, better off left alone\n\n[Chorus]\n'Cause I'm not the one\nNo I'm not the one\nYou wanted it all, but I'll give you, give you none\nNo, I'm not the one\n\n[Verse 2]\nWell, like a toy, to a kid\nI said jump, and mama you did\nAnd you know, your daddy knows and your mama knows that's wrong\nSo now it's time for me to move on\n\n[Chorus]\nBecause I'm not the one\nNo I'm not the one\nYou wanted it all, but I give you, give you none\nI'm not the one\n\n[Verse 3]\nYou think that I'm normal\nAll these years I'm just trying to warn you\nYou'd do good to move on\nNo it won't, it won't hurt me none\n\n[Chorus]\n'Cause I'm not the one\nNo I'm not the one\nYou wanted it all, but I give you, give you none\nBecause I'm not the one\nNo I'm not the one\n\n"},
#  {'genre': 'Hip-Hop',
#   'artist_name': 'Jay Rock',
#   'track_name': 'Gumbo',
#   'popularity': 50,
#   'acousticness': 0.278,
#   'danceability': 0.638,
#   'duration_ms': 243248,
#   'energy': 0.778,
#   'instrumentalness': 4.4e-06,
#   'key': 'F',
#   'liveness': 0.67,
#   'loudness': -8.292,
#   'mode': 'Minor',
#   'speechiness': 0.251,
#   'tempo': 101.042,
#   'time_signature': '4/4',
#   'valence': 0.31,
#   'Alternative': 0,
#   'Anime': 0,
#   'Blues': 0,
#   'Children’s Music': 0,
#   'Classical': 0,
#   'Country': 0,
#   'Dance': 0,
#   'Electronic': 0,
#   'Folk': 0,
#   'Hip-Hop': 1,
#   'Indie': 0,
#   'Jazz': 0,
#   'Movie': 0,
#   'Pop': 0,
#   'R&B': 0,
#   'Rap': 0,
#   'Reggae': 0,
#   'Reggaeton': 0,
#   'Rock': 0,
#   'Ska': 0,
#   'Soul': 0,
#   'Soundtrack': 0,
#   'World': 0,
#   'api_path': '/songs/2164503',
#   'apple_music_id': 1031704253.0,
#   'apple_music_player_url': 'https://genius.com/songs/2164503/apple_music_player',
#   'lyrics_url': 'https://genius.com/Jay-rock-gumbo-lyrics',
#   'spotify_url': 'https://open.spotify.com/track/6mDBmG64QSg09onp4DsGX8',
#   'lyrics': '\n\n[Produced by J. LBS]\n\n[Verse 1]\nKeep it one hundred, I’m one hundred and one\nI ain’t talking dalmatians up under the sun\nOn the road to Damascus, gun and a suit\nYou either coming with some products or you coming for loot\nI’m coming with the peace so I’m chucking the deuce\nI ain’t tryna run a train I’m just in the caboose\nAnd I’m tryna give these niggas the truth\nI ain’t ‘bout to spazz on ‘em, give ‘em light\nI’m just doing my Zeus\nRubbing on her body just like a masseuse\nAnd it’s money like a hobby for you to seduce\nBut if you blink twice nigga you can Medus\'\nSee the snakes in here, look there\'s hate in there\nI pray that you niggas all playing fair\nYou can’t help but stare as you face the glare, yeah\nI’m not up on in short yellow\nWith a helmet on my head while I’m eating marshmallows\nPlaying jigsaw while I’m picking off devils\nI can rock this shit on all levels\nStraight up out the ES, journey over BS\nI’m like a hundred kilos stuffed in the Prius\nI’m going hard ‘til they free us\n\n[Hook]\nHold up wait a minute\nLet me put some season in this Gumbo\nHold up wait a minute\nLet me put some season in this Gumbo\nWhole lot of flavor, flavor\nWhole lot of flavor, flavor\nWhole lot of flavor, flavor\nWhole lot of flavor, for you\nWhole lot of flavor, flavor\nWhole lot of flavor, flavor\nWhole lot of flavor, flavor\nWhole lot of flavor, for you\n\n[Verse 2]\nHave you ever put your hand over fire\nJust to see what you could tolerate?\nAnd you can find no escape\nLife is a Dominatrix waiting for shit to pollinate\nTo make you mind your mistakes\nKeeping my chin down, nose clean, with my guards up\nCharged up ‘cause this ghetto got me scarred up\nYes, I’m the child with the crookedest smile\nLook at my foul, look at what the star bucks\nYou can’t swim if you don’t paddle\nWake up in the morning with my nose to the gravel\nBloodhound, for that federal reserve note\nThat’s when I noticed the switch, niggas is turncoats\nIt\'s the way of the world, carry the weight of the world\nCarry a blade too, for they forsake you\nYeah, I’m the vision, from the night I was born\nTo be the eye of the tiger in the eye of the storm\nEye on the clock, ain’t no need for alarms\nJust get on your A-game when it’s time to perform\nYeah, and I can show you what it feels like\nThe moment they want you defeated but yet you still fight\nSo what it feel like?\n\n[Hook]\nHold up wait a minute\nLet me put some season in this Gumbo\nHold up wait a minute\nLet me put some season in this Gumbo\nWhole lot of flavor, flavor\nWhole lot of flavor, flavor\nWhole lot of flavor, flavor\nWhole lot of flavor, for you\nWhole lot of flavor, flavor\nWhole lot of flavor, flavor\nWhole lot of flavor, flavor\nWhole lot of flavor, for you\n\n[Skit]\n- "Hold up, wait a minute / Let me put some season in this gumbo"\n- Nigga, shut the fuck up! Hey, hey! I\'m tryna play you this new Rock, and you still singin\' that shit. No nigga, new Rock! My nigga...\n- But it ain\'t this gumbo from Mrs. Johnson\n- Man, fuck you and Mrs. Johnson!\n- Nigga, what you sayin? That\'s my Sunday school teacher, dawg. Look, if it ain\'t better than this gumbo I got from Mrs. Johnson then we gon\' have some real problems, man. I\'m just sayin\'\n- Look, my nigga. Relax, my nigga. Listen to this shit\n\n'}]

# %%
help(Predictor.from_archive)
# Out:
# Help on method from_archive in module allennlp.predictors.predictor:
#
# from_archive(archive: allennlp.models.archival.Archive, predictor_name: str = None, dataset_reader_to_load: str = 'validation') -> 'Predictor' method of builtins.type instance
#     Instantiate a `Predictor` from an [`Archive`](../models/archival.md);
#     that is, from the result of training a model. Optionally specify which `Predictor`
#     subclass; otherwise, we try to find a corresponding predictor in `DEFAULT_PREDICTORS`, or if
#     one is not found, the base class (i.e. `Predictor`) will be used. Optionally specify
#     which [`DatasetReader`](../data/dataset_readers/dataset_reader.md) should be loaded;
#     otherwise, the validation one will be used if it exists followed by the training dataset reader.

# %%
df.track_id[0]
# Out:
# '14msK75pk3pA33pzPVNtBF'
